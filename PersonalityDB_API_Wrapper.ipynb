# %%
import requests

# %%
class PersonalityDatabase:

    def __init__(self):

        self.host = "https://api.personality-database.com/api/v1/"
        self.payload = {
            "query": "",
            "is_web": False,
            "type_filter": "",
            "cat_id": "",
            "list_type": "4LETTER",
            "per_page": 1,
            "next_offset": 0,
            "new_search": True}

    @staticmethod
    def get_info(r, i):
        raw = r.json()
        id = raw['items'][i]['id']
        user_id = raw['items'][i]['user_id']
        mbti_profile = raw['items'][i]['mbti_profile']
        wiki_description = raw['items'][i]['wiki_description']
        category = raw['items'][i]['category']
        mostCommonValue = raw['items'][i]['mostCommonValue']
        subcategory = raw['items'][i]['subcategory']
        profile_image_url = raw['items'][i]['profile_image_url']

        return_dict = {'id': id, 'name': mbti_profile, 'desc': wiki_description, 'category': category,
                       'sub_category': subcategory}

        if wiki_description is '':
            return_dict['desc'] = "This persona does not have any description available."
        if raw['items'][i]['image_exists']:
            return_dict['avatar'] = profile_image_url
        try:
            mbti, enneagram = mostCommonValue.split()
            return_dict['mbti'] = mbti
            return_dict['enneagram'] = enneagram
        except:
            if mostCommonValue != '':
                return_dict['mbti'] = mostCommonValue
            else:
                return_dict['type'] = None
                print('MBTI type is empty!')


        return return_dict

    def search(self, query, i=0, cat_id=None, type_filter=None, list_type="ENNEATYPE", clean=True):
        self.payload['query'] = query
        self.payload['cat_id'] = cat_id
        self.payload['type_filter'] = type_filter
        self.payload['list_type'] = list_type

        req = requests.post(self.host + 'search', json=self.payload)
        if clean:
            return self.get_info(req, i=i)
        else:
            return req

    def get_profile(self, id):
        req = requests.post(self.host + 'profile/{}'.format(id))
        return req

# %% [markdown]
# ## Usage
# You can use this wrapper in two ways: clean (all essential variables are already parsed) and just raw request.

# %%
db = PersonalityDatabase()

# %% [markdown]
# ### Return Request

# %%
req = db.search('Kakyoin', i=1, clean=False)
req.json()
# Out:
# {'profile_count': 0,
#  'items': [{'id': 165716,
#    'user_id': 6216,
#    'sub_cat_id': 10628,
#    'mbti_profile': 'Noriaki Kakyoin',
#    'wiki_description': '',
#    'theCount': 0,
#    'vote_count_enneagram': 0,
#    'watch_count': 0,
#    'chatCount': 0,
#    'allow_voting': 1,
#    'subcategory': "Jojo's Copyright Free Adventures",
#    'category': 'Television',
#    'is_watching': None,
#    'user_profile_id': '',
#    'enneagram_vote_id': '',
#    'profile_image_url': 'https://api.personality-database.com/profile_images/165716.png',
#    'mostCommonValue': '',
#    'image_exists': False},
#   {'id': 5209,
#    'user_id': 1887,
#    'sub_cat_id': 638,
#    'mbti_profile': 'Noriaki Kakyoin',
#    'wiki_description': 'レロレロ',
#    'theCount': 208,
#    'vote_count_enneagram': 105,
#    'watch_count': 119,
#    'chatCount': 98,
#    'allow_voting': 1,
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'category': 'Anime',
#    'is_watching': None,
#    'user_profile_id': '',
#    'enneagram_vote_id': '',
#    'profile_image_url': 'https://api.personality-database.com/profile_images/5209.png?credit_id=85711',
#    'mostCommonValue': 'INTP 5w4',
#    'image_exists': True},
#   {'id': 132778,
#    'user_id': 30732,
#    'sub_cat_id': 638,
#    'mbti_profile': 'Jouta Kujo',
#    'wiki_description': 'ｋａｋｙｏｉｎ\u3000ｄｉｄ\u3000ｙｏｕ\u3000ｌａｙ\u3000ｔｈｉｓ\u3000ｅｇｇ\u3000？？？',
#    'theCount': 13,
#    'vote_count_enneagram': 9,
#    'watch_count': 3,
#    'chatCount': 10,
#    'allow_voting': 1,
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'category': 'Anime',
#    'is_watching': None,
#    'user_profile_id': '',
#    'enneagram_vote_id': '',
#    'profile_image_url': 'https://api.personality-database.com/profile_images/132778.png?credit_id=66741',
#    'mostCommonValue': 'ESFJ 5w4',
#    'image_exists': True}],
#  'type_search': False}

# %% [markdown]
# ### Return Cleaned Data

# %%
req = db.search('Kakyoin', i=1, clean=True)
req
# Out:
# {'id': 5209,
#  'name': 'Noriaki Kakyoin',
#  'desc': 'レロレロ',
#  'category': 'Anime',
#  'sub_category': 'JoJo no Kimyou na Bouken',
#  'avatar': 'https://api.personality-database.com/profile_images/5209.png?credit_id=85711',
#  'mbti': 'INTP',
#  'enneagram': '5w4'}

# %% [markdown]
# ### Limitations
# Due to limitation from PersonalityDatabase API you have to use `get_profile(id)` to get every information besides MBTI and Enneagram.

# %%
req = db.get_profile(5209)
req.json()
# Out:
# {'id': 5209,
#  'sub_cat_id': 638,
#  'user_id': 1887,
#  'is_active': 1,
#  'is_approved': 1,
#  'edit_lock': 1,
#  'edit_lock_picture': 1,
#  'display_order': 1987,
#  'is_featured': 0,
#  'vote_count': 208,
#  'vote_count_enneagram': 105,
#  'watch_count': 119,
#  'comment_count': 98,
#  'allow_voting': 1,
#  'allow_commenting': 1,
#  'mbti_profile': 'Noriaki Kakyoin',
#  'profile_name_searchable': 'noriakikakyoin',
#  'featured_title': '',
#  'linked_with': '',
#  'wiki_description': 'レロレロ',
#  'mbti_type': 'INTP 5w4',
#  'category': 'Anime',
#  'subcategory': 'JoJo no Kimyou na Bouken',
#  'alt_subcategory': "JoJo's Bizarre Adventure",
#  'image_exists': True,
#  'user_vote': '',
#  'enneagram_vote': '',
#  'user_profile_id': 0,
#  'enneagram_vote_id': 0,
#  'is_watching': 0,
#  'profile_image_credit_type': 0,
#  'profile_image_credit_url': '',
#  'profile_image_credit_id': '85711',
#  'profile_image_credit': '',
#  'profile_image_url': 'https://api.personality-database.com/profile_images/5209.png?credit_id=85711',
#  'contributor': 'luger2000',
#  'contributor_create_date': '2017-01-07 10:56:08',
#  'category_is_fictional': '1',
#  'related_subcategories': '',
#  'pdb_page_owner': 0,
#  'pdb_comment_access': 1,
#  'pdb_public_access': 1,
#  'related_profiles': [{'id': '5489',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jonathan Joestar',
#    'user_id': '2041',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5488',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Joseph Joestar',
#    'user_id': '2041',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5206',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jotaro Kujo',
#    'user_id': '1887',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5208',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Josuke Higashikata',
#    'user_id': '1887',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '14646',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Giorno Giovanna',
#    'user_id': '5188',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '26929',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jolyne Cujoh',
#    'user_id': '9688',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30298',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Johnny Joestar',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '38225',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Josuke Higashikata (Part 8)',
#    'user_id': '5599',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '9037',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Dio Brando',
#    'user_id': '3861',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5490',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Robert E. O. Speedwagon',
#    'user_id': '2041',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '34140',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Baron Will A. Zeppeli',
#    'user_id': '12060',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5491',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Caesar Anthonio Zeppeli',
#    'user_id': '2041',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '14645',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Kars',
#    'user_id': '5188',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '19091',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Lisa Lisa',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5209',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Noriaki Kakyoin',
#    'user_id': '1887',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '28455',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jean Pierre Polnareff',
#    'user_id': '10183',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '28456',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Muhammad Avdol',
#    'user_id': '10183',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '9038',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Iggy',
#    'user_id': '3861',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '5207',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yoshikage Kira',
#    'user_id': '1887',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '9040',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Koichi Hirose',
#    'user_id': '3861',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '29270',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Okuyasu Nijimura',
#    'user_id': '10705',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '9039',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Rohan Kishibe',
#    'user_id': '3861',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41058',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yukako Yamagishi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '21191',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Bruno Bucciarati',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '21192',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Leone Abbacchio',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '19548',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Guido Mista',
#    'user_id': '7217',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '14865',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Pannacotta Fugo',
#    'user_id': '5917',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '21193',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Narancia Ghirga',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '29269',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Trish Una',
#    'user_id': '10705',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30313',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Diavolo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30314',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Vinegar Doppio',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '14647',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Enrico Pucci',
#    'user_id': '5188',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30618',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Ermes Costello',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30299',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Gyro Zeppeli',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30300',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Funny Valentine',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '29660',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Diego Brando',
#    'user_id': '10565',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '38228',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yasuho Hirose',
#    'user_id': '5599',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71065',
#    'sub_cat_id': '638',
#    'mbti_profile': '『 Anubis 』',
#    'user_id': '6332',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71207',
#    'sub_cat_id': '638',
#    'mbti_profile': '『 Wonder of U 』(Satoru Akefu)',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '53909',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Aisho Dainenjiyama',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41048',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Akira Otoishi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41028',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Alessi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151164',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Anakiss',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151893',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Andre Boom Boom',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71742',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Angelica Attanasio',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41052',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Angelo Katagiri',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '32948',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Anne',
#    'user_id': '7306',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62566',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Axl RO',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41059',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Aya Tsuji',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71127',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Baby Face (Junior)',
#    'user_id': '10705',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151894',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Benjamin Boom Boom',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '53915',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Blackmore',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30619',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Boingo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '131014',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Bruford',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41023',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Cameo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71746',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Cannolo Murolo',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41064',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Carne',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '155709',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Chaka',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71064',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Cheap Trick',
#    'user_id': '6332',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30311',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Cioccolata',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '150930',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Coco Jumbo',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41797',
#    'sub_cat_id': '638',
#    'mbti_profile': 'D an G',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '53913',
#    'sub_cat_id': '638',
#    'mbti_profile': 'D-I-S-C-O',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40340',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Daiya Higashikata',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41043',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Daniel J. D’Arby',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '130399',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Dario Brando',
#    'user_id': '23315',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41038',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Devo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '73658',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Diego Brando From Another World',
#    'user_id': '10565',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '129250',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Dire',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62571',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Dolomité',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '84248',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Donatella Una',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41068',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Donatello Versus',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '149043',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Donovan',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62567',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Dr. Ferdinand',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30303',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Emporio Alniño',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30296',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Enyaba the Hag',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '19081',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Erina Pendleton',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30297',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Esidisi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '9036',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Foo Fighters',
#    'user_id': '3861',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41036',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Forever',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30288',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Formaggio',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '155832',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Fortuneteller',
#    'user_id': '34628',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '175247',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Fritz Von Stroheim',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '175835',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Gaucho',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '98845',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Gelato',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '67056',
#    'sub_cat_id': '638',
#    'mbti_profile': 'George Joestar (Part 1)',
#    'user_id': '6216',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '160915',
#    'sub_cat_id': '638',
#    'mbti_profile': 'George Joestar (Part 7)',
#    'user_id': '80050',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71747',
#    'sub_cat_id': '638',
#    'mbti_profile': 'George Joestar II',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30293',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Ghiaccio',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '152224',
#    'sub_cat_id': '638',
#    'mbti_profile': "Giorno's Mother",
#    'user_id': '17471',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41024',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Gray Fly',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151901',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Green Baby',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '156018',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Gregorio Zeppeli',
#    'user_id': '22299',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41798',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Guccio',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41799',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Gwess',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40342',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Hato Higashikata',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30295',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Hayato Kawajiri',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30294',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Hol Horse',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '170181',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Holy Joestar-Kira',
#    'user_id': '74515',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41047',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Holy Kujo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30301',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Hot Pants',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30289',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Illuso',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41025',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Imposter Captain Tennille',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151158',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Irene',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41026',
#    'sub_cat_id': '638',
#    'mbti_profile': 'J. Geil / Centerfold',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '129595',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jack the Ripper',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151336',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jesus Christ',
#    'user_id': '34628',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40344',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jobin Higashikata',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41800',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Johngalli A',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '134867',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jorge "Joji" Joestar',
#    'user_id': '15412',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '46690',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Josefumi Kujo',
#    'user_id': '11203',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40341',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Joshu Higashikata',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '132778',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Jouta Kujo',
#    'user_id': '30732',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '53910',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Kaato Higashikata',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '104062',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Karera Sakunami',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '14648',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Keicho Nijimura',
#    'user_id': '5188',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41053',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Ken Oyanagi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41801',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Kenzou',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '155725',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Khan',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40343',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Kyo Nijimura',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '177661',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Kyoka Izumi',
#    'user_id': '6216',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151895',
#    'sub_cat_id': '638',
#    'mbti_profile': 'L. A. Boom Boom',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41802',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Lang Wrangler',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '53714',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Leaky-Eye Luca',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '172027',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Loccobarocco',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '149040',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Loggins',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30304',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Lucy Steel',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30309',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Magenta Magenta',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '156680',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Malèna',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41027',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mannish Boy',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '175245',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Marco',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41042',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mariah',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30315',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mario Zucchero',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '156686',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mark',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '150939',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mary Joestar',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '69228',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Masazo Kinoto',
#    'user_id': '18243',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71741',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Massimo Volpe',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30292',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Melone',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '149041',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Messina',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41030',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Midler',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62568',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mike O.',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41054',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mikitaka Hazekura',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41803',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Miraschon',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '112971',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mitsuba Higashikata',
#    'user_id': '18635',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41804',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Miuccia Miuller',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30307',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mountain Tim',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '173969',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Mrs. Robinson',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41035',
#    'sub_cat_id': '638',
#    'mbti_profile': 'N’Doul',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '177472',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Nanase Fujikura',
#    'user_id': '6216',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30302',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Narciso Anasui',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41045',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Nena',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40339',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Norisuke Higashikata IV',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '61296',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Nukesaku',
#    'user_id': '11620',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '70392',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Number 5',
#    'user_id': '13650',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41039',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Oingo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '49158',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Ojiro Sasame',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '53914',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Oyecomova',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '46875',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Pericolo',
#    'user_id': '11620',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30291',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Pesci',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41031',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Pet Shop',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '150935',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Poco',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '150938',
#    'sub_cat_id': '638',
#    'mbti_profile': "Poco's Sister",
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30306',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Pocoloco',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30287',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Polpo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62572',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Poor Tom',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62570',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Pork Pie Hat Kid',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30290',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Prosciutto',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '54796',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Rai Mamezuku',
#    'user_id': '12251',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '35634',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Reimi Sugimoto',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41067',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Rikiel',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30310',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Ringo Roadagain',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30060',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Risotto Nero',
#    'user_id': '9711',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '173900',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Romeo Jisso',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '162768',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Roses',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41032',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Rubber Soul',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '19084',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Rudol von Stroheim',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30316',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Sale',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30305',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Sandman / Soundman',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '82635',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Santana',
#    'user_id': '7596',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '135516',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Scarlet Valentine',
#    'user_id': '14294',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41065',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Scolippi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30312',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Secco',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71745',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Sheila E',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41056',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Shigekiyo “Shigechi” Yangu',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '58456',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Shinobu Kawajiri',
#    'user_id': '13175',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '155742',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Shizuka Joestar',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '138485',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Slow Dancer',
#    'user_id': '65008',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41658',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Smokey Brown',
#    'user_id': '8964',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '98844',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Sorbet',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41069',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Sports Maxx',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41062',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Squalo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41033',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Steely Dan',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '54534',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Steven Steel',
#    'user_id': '9646',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '84095',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Straizo',
#    'user_id': '18747',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '178131',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Sugar Mountain',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '34143',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Suzi Q',
#    'user_id': '12060',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '151334',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Takuma Hasumi',
#    'user_id': '34628',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40345',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tamaki Damo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41057',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tamami Kobayashi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '131067',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tarkus',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41044',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Telence T. D’Arby',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41049',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Terunosuke Miyamoto',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41805',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Thunder McQueen',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41063',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tiziano',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '60827',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tomoko Higashikata',
#    'user_id': '11620',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41051',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tonio Trussardi',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '128871',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tonpetty',
#    'user_id': '22348',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '121360',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tooru',
#    'user_id': '18635',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41055',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Toshikazu Hazamada',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '59676',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Toyohiro Kanedaichi',
#    'user_id': '10705',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40347',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Tsurugi Higashikata',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41066',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Ungalo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62573',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Urban Guerilla',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '175799',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Urmd Abdul',
#    'user_id': '15697',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '138482',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Valkyrie',
#    'user_id': '65008',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41029',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Vanilla Ice',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71744',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Vittorio Cataldi',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41806',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Viviano Westwood',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '71743',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Vladimir Kocaqi',
#    'user_id': '19295',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '19085',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Wamuu',
#    'user_id': '6642',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '28142',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Weather Report',
#    'user_id': '9480',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '30308',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Wekapipo',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '62574',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Wu Tomoki',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '120445',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yoma Hashimoto',
#    'user_id': '3278',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41060',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yoshihiro Kira',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '46221',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yoshikage Kira (Part 8)',
#    'user_id': '11203',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '40346',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yotsuyu Yagiyama',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41050',
#    'sub_cat_id': '638',
#    'mbti_profile': 'Yuya Fungami',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'},
#   {'id': '41046',
#    'sub_cat_id': '638',
#    'mbti_profile': 'ZZ',
#    'user_id': '9581',
#    'subcategory': 'JoJo no Kimyou na Bouken',
#    'group_name': 'Supernatural'}],
#  'personality_types': {'1': ['ISTJ',
#    'ESTJ',
#    'ISFJ',
#    'ESFJ',
#    'ESFP',
#    'ISFP',
#    'ESTP',
#    'ISTP',
#    'INFJ',
#    'ENFJ',
#    'INFP',
#    'ENFP',
#    'INTP',
#    'ENTP',
#    'INTJ',
#    'ENTJ'],
#   '2': ['1w2',
#    '1w9',
#    '2w1',
#    '2w3',
#    '3w2',
#    '3w4',
#    '4w3',
#    '4w5',
#    '5w4',
#    '5w6',
#    '6w5',
#    '6w7',
#    '7w6',
#    '7w8',
#    '8w7',
#    '8w9',
#    '9w1',
#    '9w8'],
#   '3': ['ESE',
#    'SEI',
#    'ILE',
#    'LII',
#    'EIE',
#    'IEI',
#    'SLE',
#    'LSI',
#    'SEE',
#    'ESI',
#    'LIE',
#    'ILI',
#    'IEE',
#    'EII',
#    'LSE',
#    'SLI'],
#   '4': ['Lawful Good',
#    'Neutral Good',
#    'Chaotic Good',
#    'Lawful Neutral',
#    'True Neutral',
#    'Chaotic Neutral',
#    'Lawful Evil',
#    'Neutral Evil',
#    'Chaotic Evil'],
#   '5': ['so/sp', 'so/sx', 'sp/so', 'sp/sx', 'sx/so', 'sx/sp'],
#   '6': ['125',
#    '126',
#    '127',
#    '135',
#    '136',
#    '137',
#    '145',
#    '146',
#    '147',
#    '152',
#    '153',
#    '154',
#    '162',
#    '163',
#    '164',
#    '172',
#    '173',
#    '174',
#    '215',
#    '216',
#    '217',
#    '251',
#    '258',
#    '259',
#    '261',
#    '268',
#    '269',
#    '271',
#    '278',
#    '279',
#    '285',
#    '286',
#    '287',
#    '295',
#    '296',
#    '297',
#    '315',
#    '316',
#    '317',
#    '351',
#    '358',
#    '359',
#    '361',
#    '368',
#    '369',
#    '371',
#    '378',
#    '379',
#    '385',
#    '386',
#    '387',
#    '395',
#    '396',
#    '397',
#    '415',
#    '416',
#    '417',
#    '451',
#    '458',
#    '459',
#    '461',
#    '468',
#    '469',
#    '471',
#    '478',
#    '479',
#    '485',
#    '486',
#    '487',
#    '495',
#    '496',
#    '497',
#    '512',
#    '513',
#    '514',
#    '521',
#    '528',
#    '529',
#    '531',
#    '538',
#    '539',
#    '541',
#    '548',
#    '549',
#    '582',
#    '583',
#    '584',
#    '592',
#    '593',
#    '594',
#    '612',
#    '613',
#    '614',
#    '621',
#    '628',
#    '629',
#    '631',
#    '638',
#    '639',
#    '641',
#    '648',
#    '649',
#    '682',
#    '683',
#    '684',
#    '692',
#    '693',
#    '694',
#    '712',
#    '713',
#    '714',
#    '721',
#    '728',
#    '729',
#    '731',
#    '738',
#    '739',
#    '741',
#    '748',
#    '749',
#    '782',
#    '783',
#    '784',
#    '792',
#    '793',
#    '794',
#    '825',
#    '826',
#    '827',
#    '835',
#    '836',
#    '837',
#    '845',
#    '846',
#    '847',
#    '852',
#    '853',
#    '854',
#    '862',
#    '863',
#    '864',
#    '872',
#    '873',
#    '874',
#    '925',
#    '926',
#    '927',
#    '935',
#    '936',
#    '937',
#    '945',
#    '946',
#    '947',
#    '952',
#    '953',
#    '954',
#    '962',
#    '963',
#    '964',
#    '972',
#    '973',
#    '974'],
#   '7': ['Choleric [Dominant]',
#    'Melancholic [Dominant]',
#    'Phlegmatic [Dominant]',
#    'Sanguine [Dominant]',
#    'Choleric-Melancholic',
#    'Choleric-Phlegmatic',
#    'Choleric-Sanguine',
#    'Melancholic-Choleric',
#    'Melancholic-Phlegmatic',
#    'Melancholic-Sanguine',
#    'Phlegmatic-Choleric',
#    'Phlegmatic-Melancholic',
#    'Phlegmatic-Sanguine',
#    'Sanguine-Choleric',
#    'Sanguine-Melancholic',
#    'Sanguine-Phlegmatic']},
#  'breakdown_systems': {'1': [{'myValue': 'INTP', 'theCount': '183'},
#    {'myValue': 'INTJ', 'theCount': '6'},
#    {'myValue': 'INFP', 'theCount': '5'},
#    {'myValue': 'ISFJ', 'theCount': '5'},
#    {'myValue': 'ISFP', 'theCount': '4'},
#    {'myValue': 'INFJ', 'theCount': '3'},
#    {'myValue': 'ENTP', 'theCount': '1'},
#    {'myValue': 'ESFJ', 'theCount': '1'}],
#   '2': [{'myValue': '5w4', 'theCount': '93'},
#    {'myValue': '4w5', 'theCount': '4'},
#    {'myValue': '5w6', 'theCount': '3'},
#    {'myValue': '6w5', 'theCount': '3'},
#    {'myValue': '1w2', 'theCount': '1'},
#    {'myValue': '7w6', 'theCount': '1'}],
#   '5': [{'myValue': 'sp/sx', 'theCount': '11'},
#    {'myValue': 'sp/so', 'theCount': '7'},
#    {'myValue': 'so/sp', 'theCount': '2'},
#    {'myValue': 'so/sx', 'theCount': '1'}],
#   '6': [{'myValue': '594', 'theCount': '13'},
#    {'myValue': '317', 'theCount': '1'}],
#   '3': [{'myValue': 'ILI', 'theCount': '14'},
#    {'myValue': 'LII', 'theCount': '1'}],
#   '4': [{'myValue': 'Neutral Good', 'theCount': '31'},
#    {'myValue': 'Lawful Neutral', 'theCount': '2'}],
#   '7': [{'myValue': 'Phlegmatic [Dominant]', 'theCount': '11'},
#    {'myValue': 'Melancholic [Dominant]', 'theCount': '1'},
#    {'myValue': 'Melancholic-Sanguine', 'theCount': '1'},
#    {'myValue': 'Phlegmatic-Melancholic', 'theCount': '1'},
#    {'myValue': 'Sanguine-Choleric', 'theCount': '1'}]},
#  'systems': [{'id': '1',
#    'system_name': 'Four Letter',
#    'hex_color': '#888888',
#    'personality_type': 'XXXX',
#    'vote_id': '0'},
#   {'id': '2',
#    'system_name': 'Enneagram',
#    'hex_color': '#006775',
#    'personality_type': 'XXXX',
#    'vote_id': '0'},
#   {'id': '5',
#    'system_name': 'Instinctual Variant',
#    'hex_color': '#006775',
#    'personality_type': 'XXXX',
#    'vote_id': '0'},
#   {'id': '6',
#    'system_name': 'Tritype',
#    'hex_color': '#006775',
#    'personality_type': 'XXXX',
#    'vote_id': '0'},
#   {'id': '3',
#    'system_name': 'Socionics',
#    'hex_color': '#888888',
#    'personality_type': 'XXXX',
#    'vote_id': '0'},
#   {'id': '4',
#    'system_name': 'Alignment',
#    'hex_color': '#888888',
#    'personality_type': 'XXXX',
#    'vote_id': '0'},
#   {'id': '7',
#    'system_name': 'Temperaments',
#    'hex_color': '#888888',
#    'personality_type': 'XXXX',
#    'vote_id': '0'}],
#  'breakdown': [{'myValue': 'INTP', 'theCount': '183'},
#   {'myValue': 'INTJ', 'theCount': '6'},
#   {'myValue': 'INFP', 'theCount': '5'},
#   {'myValue': 'ISFJ', 'theCount': '5'},
#   {'myValue': 'ISFP', 'theCount': '4'},
#   {'myValue': 'INFJ', 'theCount': '3'},
#   {'myValue': 'ENTP', 'theCount': '1'},
#   {'myValue': 'ESFJ', 'theCount': '1'}],
#  'stats': [{'type': 'I', 'percentage': '99%'},
#   {'type': 'N', 'percentage': '95%'},
#   {'type': 'T', 'percentage': '91%'},
#   {'type': 'P', 'percentage': '93%'}],
#  'functions': ['Ti', 'Ne', 'Si', 'Fe', 'INTP']}
